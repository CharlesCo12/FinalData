# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
dat=pd.read_csv('mobility-trends.csv')

# %%
dat
# Out:
#              geo_type   region transportation_type        date   value
# 0      country/region  Albania             driving  2020-01-13  100.00
# 1      country/region  Albania             driving  2020-01-14   95.30
# 2      country/region  Albania             driving  2020-01-15  101.43
# 3      country/region  Albania             driving  2020-01-16   97.20
# 4      country/region  Albania             driving  2020-01-17  103.55
# ...               ...      ...                 ...         ...     ...
# 41470            city   Zurich             walking  2020-04-22   72.35
# 41471            city   Zurich             walking  2020-04-23   73.64
# 41472            city   Zurich             walking  2020-04-24   76.72
# 41473            city   Zurich             walking  2020-04-25   78.56
# 41474            city   Zurich             walking  2020-04-26   74.29
#
# [41475 rows x 5 columns]

# %%
dat.keys()
# Out:
# Index(['geo_type', 'region', 'transportation_type', 'date', 'value'], dtype='object')

# %%
i=np.where(dat['region']=='Colombia')

# %%
plt.scatter(dat['date'][i[0]],dat['value'][i[0]],s=2)

# %%
i1=np.where((dat['region']=='Colombia') & (dat['transportation_type']=='driving'))
i2=np.where((dat['region']=='Colombia') & (dat['transportation_type']=='transit'))
i3=np.where((dat['region']=='Colombia') & (dat['transportation_type']=='walking'))

# %%
plt.scatter(dat['date'][i1[0]],dat['value'][i1[0]],s=2,label='driving')
plt.scatter(dat['date'][i3[0]],dat['value'][i3[0]],s=2,label='walking')
plt.legend(loc=0.0)
plt.title('Types of Transportation in Colombia')
# Out:
# Text(0.5, 1.0, 'Types of Transportation in Colombia')

# %%
dat_2=pd.read_csv('current-data-on-the-geographic-distribution-of-covid-19-cases-worldwide.csv')

# %%
dat_2
# Out:
#        daterep  day  month  year  cases  deaths countriesandterritories geoid  \
# 0          NaN   28      4  2020    172       0             Afghanistan    AF
# 1          NaN   27      4  2020     68      10             Afghanistan    AF
# 2          NaN   26      4  2020    112       4             Afghanistan    AF
# 3          NaN   25      4  2020     70       1             Afghanistan    AF
# 4          NaN   24      4  2020    105       2             Afghanistan    AF
# ...        ...  ...    ...   ...    ...     ...                     ...   ...
# 13618      NaN   25      3  2020      0       0                Zimbabwe    ZW
# 13619      NaN   24      3  2020      0       1                Zimbabwe    ZW
# 13620      NaN   23      3  2020      0       0                Zimbabwe    ZW
# 13621      NaN   22      3  2020      1       0                Zimbabwe    ZW
# 13622      NaN   21      3  2020      1       0                Zimbabwe    ZW
#
#       countryterritorycode  popdata2018 continentexp
# 0                      AFG   37172386.0         Asia
# 1                      AFG   37172386.0         Asia
# 2                      AFG   37172386.0         Asia
# 3                      AFG   37172386.0         Asia
# 4                      AFG   37172386.0         Asia
# ...                    ...          ...          ...
# 13618                  ZWE   14439018.0       Africa
# 13619                  ZWE   14439018.0       Africa
# 13620                  ZWE   14439018.0       Africa
# 13621                  ZWE   14439018.0       Africa
# 13622                  ZWE   14439018.0       Africa
#
# [13623 rows x 11 columns]

# %%
dat_2.keys()
# Out:
# Index(['daterep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesandterritories', 'geoid', 'countryterritorycode',
#        'popdata2018', 'continentexp'],
#       dtype='object')

# %%
j=np.where(dat_2['countriesandterritories']=='Colombia')

# %%
n=len(j[0])

# %%
np.array(dat_2)[j[0],:]
# Out:
# array([[nan, 28, 4, 2020, 218, 10, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 27, 4, 2020, 237, 10, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 26, 4, 2020, 261, 8, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 25, 4, 2020, 320, 10, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 24, 4, 2020, 205, 9, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 23, 4, 2020, 207, 10, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 22, 4, 2020, 172, 7, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 21, 4, 2020, 185, 10, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 20, 4, 2020, 171, 13, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 19, 4, 2020, 182, 13, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 18, 4, 2020, 206, 9, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 17, 4, 2020, 128, 13, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 16, 4, 2020, 126, 4, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 15, 4, 2020, 127, 15, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 14, 4, 2020, 76, 3, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 13, 4, 2020, 67, 9, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 12, 4, 2020, 236, 20, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 11, 4, 2020, 250, 11, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 10, 4, 2020, 169, 14, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 9, 4, 2020, 274, 5, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 8, 4, 2020, 201, 4, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 7, 4, 2020, 94, 11, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 6, 4, 2020, 79, 3, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 5, 4, 2020, 139, 7, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 4, 4, 2020, 106, 6, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 3, 4, 2020, 96, 2, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 2, 4, 2020, 159, 1, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 1, 4, 2020, 108, 2, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 31, 3, 2020, 96, 4, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 30, 3, 2020, 94, 4, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 29, 3, 2020, 69, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 28, 3, 2020, 48, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 27, 3, 2020, 21, 2, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 26, 3, 2020, 92, 1, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 25, 3, 2020, 72, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 24, 3, 2020, 71, 1, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 23, 3, 2020, 25, 1, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 22, 3, 2020, 52, 1, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 21, 3, 2020, 30, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 20, 3, 2020, 26, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 19, 3, 2020, 37, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 18, 3, 2020, 8, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 17, 3, 2020, 12, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 16, 3, 2020, 11, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 15, 3, 2020, 18, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 14, 3, 2020, 7, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 12, 3, 2020, 6, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 10, 3, 2020, 2, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America'],
#        [nan, 7, 3, 2020, 1, 0, 'Colombia', 'CO', 'COL', 49648685.0,
#         'America']], dtype=object)

# %%
a=[]
for i in range(n):
    a.append(str(np.array(dat_2)[j[0],1][i])+'/0'+str(np.array(dat_2)[j[0],2][i])+'/2020')

# %%
death = dat_2['deaths'][j[0]]
cases = dat_2['cases'][j[0]]

# %%
x=abs(np.arange(1-n,1))
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.title('Deaths per day')
plt.scatter(x,death,s=2)
plt.subplot(122)
plt.title('Cases per day')
plt.scatter(x,cases,s=2)

# %%
y=abs(np.arange(n))
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.title('Deaths Total')
plt.scatter(y,np.cumsum(np.array(death)),s=2)
plt.subplot(122)
plt.title('Cases Total')
plt.scatter(y,np.cumsum(np.array(cases)),s=2)

# %%
np.cumsum(np.array(death))
# Out:
# array([ 10,  20,  28,  38,  47,  57,  64,  74,  87, 100, 109, 122, 126,
#        141, 144, 153, 173, 184, 198, 203, 207, 218, 221, 228, 234, 236,
#        237, 239, 243, 247, 247, 247, 249, 250, 250, 251, 252, 253, 253,
#        253, 253, 253, 253, 253, 253, 253, 253, 253, 253])

# %%
data_3=pd.read_csv('coronavirus-world-airport-impacts.csv')

# %%
data_3.keys()
# Out:
# Index(['geometry', 'ident', 'type', 'name', 'latitude_d', 'longitude',
#        'elevation', 'continent', 'iso_countr', 'iso_region', 'municipali',
#        'scheduled', 'gps_code', 'iata_code', 'status', 'objectid'],
#       dtype='object')

# %%
data_3
# Out:
#                               geometry ident            type  \
# 0            POINT (-76.5008 0.505228)  SKAS  medium_airport
# 1              POINT (-73.1848 7.1265)  SKBG  medium_airport
# 2             POINT (-74.1469 4.70159)  SKBO   large_airport
# 3             POINT (-74.7808 10.8896)  SKBQ  medium_airport
# 4             POINT (-77.3947 6.20292)  SKBS  medium_airport
# ...                                ...   ...             ...
# 3075  POINT (152.8800049 -25.31889915)  YHBA  medium_airport
# 3076  POINT (142.2899933 -10.58640003)  YHID  medium_airport
# 3077  POINT (147.3339996 -37.04750061)  YHOT  medium_airport
# 3078   POINT (143.878006 -39.87749863)  YKII  medium_airport
# 3079  POINT (141.7510071 -15.48560047)  YKOW  medium_airport
#
#                                          name  latitude_d   longitude  \
# 0                        Tres De Mayo Airport    0.505228  -76.500800
# 1                           Palonegro Airport    7.126500  -73.184800
# 2             El Dorado International Airport    4.701590  -74.146900
# 3     Ernesto Cortissoz International Airport   10.889600  -74.780800
# 4                José Celestino Mutis Airport    6.202920  -77.394700
# ...                                       ...         ...         ...
# 3075                       Hervey Bay Airport  -25.318899  152.880005
# 3076                      Horn Island Airport  -10.586400  142.289993
# 3077                     Mount Hotham Airport  -37.047501  147.334000
# 3078                      King Island Airport  -39.877499  143.878006
# 3079                        Kowanyama Airport  -15.485600  141.751007
#
#      elevation      continent iso_countr iso_region    municipali scheduled  \
# 0          815  South America         CO     CO-PUT   Puerto Asís       yes
# 1         3897  South America         CO     CO-SAN   Bucaramanga       yes
# 2         8361  South America         CO     CO-CUN        Bogota       yes
# 3           98  South America         CO     CO-ATL  Barranquilla       yes
# 4           80  South America         CO     CO-CHO  Bahía Solano       yes
# ...        ...            ...        ...        ...           ...       ...
# 3075        60      Australia         AU     AU-QLD    Hervey Bay       yes
# 3076        43      Australia         AU     AU-QLD   Horn Island       yes
# 3077      4260      Australia         AU     AU-VIC  Mount Hotham       yes
# 3078       132      Australia         AU     AU-TAS           NaN       yes
# 3079        35      Australia         AU     AU-QLD     Kowanyama       yes
#
#      gps_code iata_code        status  objectid
# 0        SKAS       PUU           NaN      3001
# 1        SKBG       BGA           NaN      3002
# 2        SKBO       BOG  Restrictions      3003
# 3        SKBQ       BAQ  Restrictions      3004
# 4        SKBS       BSC           NaN      3005
# ...       ...       ...           ...       ...
# 3075     YHBA       HVB           NaN      2996
# 3076     YHID       HID           NaN      2997
# 3077     YHOT       MHU           NaN      2998
# 3078     YKII       KNS           NaN      2999
# 3079     YKOW       KWM           NaN      3000
#
# [3080 rows x 16 columns]

# %%
p=np.where(data_3['iso_countr'] == 'CO')

# %%
data_3['municipali'][p[0]]
# Out:
# 0                  Puerto Asís
# 1                  Bucaramanga
# 2                       Bogota
# 3                 Barranquilla
# 4                 Bahía Solano
# 5                 Buenaventura
# 6                       Cúcuta
# 7                    Cartagena
# 8                         Cali
# 9                       Tumaco
# 10                     Corozal
# 11             Barrancabermeja
# 12                   Florencia
# 13                     Cartago
# 14                       Guapi
# 2291                    Ibagué
# 2292                   Ipiales
# 2293                    Carepa
# 2294                   Leticia
# 2295                  Medellín
# 2296                  Montería
# 2297                      Mitú
# 2298                 Manizales
# 2299                     Neiva
# 2300            Puerto Carreño
# 2301                   Pereira
# 2302                   Popayán
# 2303                     Pasto
# 2304               Providencia
# 2305                  Rionegro
# 2306                  Riohacha
# 2307     San José Del Guaviare
# 2308               Santa Marta
# 2309                San Andrés
# 2310    San Vicente Del Caguán
# 2311                      Tame
# 2312                    Arauca
# 2313                    Quibdó
# 2314                Valledupar
# 2315             Villavicencio
# 2316                  El Yopal
# 2317            Puerto Inírida
# 2318                   Armenia
# Name: municipali, dtype: object

# %%
plt.scatter(data_3['longitude'],data_3['latitude_d'],s=0.5)

# %%
A=set(data_3['continent'])

# %%
plt.figure(figsize=(10,6))
for i in A:
    k = np.where(data_3['continent']==i)
    plt.scatter(data_3['longitude'][k[0]],data_3['latitude_d'][k[0]],s=0.2,label=i)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.savefig('mapa_f.png')

# %%
dat_4=pd.read_csv('acaps-covid-19-government-measures-dataset.csv')

# %%
dat_4.keys()
# Out:
# Index(['id', 'country', 'iso', 'admin_level_name', 'pcode', 'region',
#        'category', 'measure', 'targeted_pop_group', 'comments',
#        'non_compliance', 'date_implemented', 'source', 'source_type', 'link',
#        'entry_date', 'alternative_source'],
#       dtype='object')

# %%
dat_4
# Out:
#         id      country  iso admin_level_name  pcode  region  \
# 0        1  Afghanistan  AFG              NaN    NaN    Asia
# 1        2  Afghanistan  AFG            Kabul    NaN    Asia
# 2        3  Afghanistan  AFG              NaN    NaN    Asia
# 3        4  Afghanistan  AFG              NaN    NaN    Asia
# 4        5  Afghanistan  AFG              NaN    NaN    Asia
# ...    ...          ...  ...              ...    ...     ...
# 4144  1959     Zimbabwe  ZWE              NaN    NaN  Africa
# 4145  1960     Zimbabwe  ZWE              NaN    NaN  Africa
# 4146  1961     Zimbabwe  ZWE              NaN    NaN  Africa
# 4147  1962     Zimbabwe  ZWE              NaN    NaN  Africa
# 4148  2956     Zimbabwe  ZWE              NaN    NaN  Africa
#
#                                     category  \
# 0                     Public health measures
# 1                     Public health measures
# 2                     Public health measures
# 3     Governance and socio-economic measures
# 4                          Social distancing
# ...                                      ...
# 4144                       Social distancing
# 4145                  Public health measures
# 4146                  Public health measures
# 4147                       Social distancing
# 4148                                Lockdown
#
#                                                 measure targeted_pop_group  \
# 0     Health screenings in airports and border cross...                  f
# 1                   Introduction of quarantine policies                  f
# 2                                   Awareness campaigns                  f
# 3     Emergency administrative structures activated ...                  f
# 4                               Limit public gatherings                  f
# ...                                                 ...                ...
# 4144                            Limit public gatherings                  f
# 4145                Introduction of quarantine policies                  f
# 4146  Health screenings in airports and border cross...                  f
# 4147                                    Schools closure                  f
# 4148                                   Partial lockdown                  f
#
#                                                comments    non_compliance  \
# 0                                                   NaN               NaN
# 1                                                   NaN               NaN
# 2                                                   NaN               NaN
# 3                                                   NaN               NaN
# 4                             Nevruz festival cancelled               NaN
# ...                                                 ...               ...
# 4144  Hospital visits have been reduced to one visit...               NaN
# 4145  All our returning residents will be subjected ...               NaN
# 4146  All our returning residents will be subjected ...               NaN
# 4147                       Zimbabwe closes all schools.               NaN
# 4148  Zimbabwe will go into lockdown for three weeks...  Arrest/Detention
#
#      date_implemented              source   source_type  \
# 0          2020-02-12  Ministry of Health    Government
# 1          2020-02-12  Ministry of Health    Government
# 2          2020-02-12  Ministry of Health    Government
# 3          2020-02-12  Ministry of Health    Government
# 4          2020-03-12                  AA         Media
# ...               ...                 ...           ...
# 4144       2020-03-24  Ministry of Health  Social media
# 4145       2020-03-24          The Herald         Media
# 4146       2020-03-24          The Herald         Media
# 4147       2020-03-24            News Day         Media
# 4148       2020-03-30         Africa News         Media
#
#                                                    link  entry_date  \
# 0     https://moph.gov.af/en/moph-held-emergency-mee...  2020-03-14
# 1     https://moph.gov.af/en/moph-held-emergency-mee...  2020-03-14
# 2     https://moph.gov.af/en/moph-held-emergency-mee...  2020-03-14
# 3     https://moph.gov.af/en/moph-held-emergency-mee...  2020-03-14
# 4     https://www.aa.com.tr/en/asia-pacific/coronavi...  2020-03-14
# ...                                                 ...         ...
# 4144  https://twitter.com/MoHCCZim/status/1242180289...  2020-03-24
# 4145  https://www.herald.co.zw/new-measures-to-stop-...  2020-03-24
# 4146  https://www.herald.co.zw/new-measures-to-stop-...  2020-03-24
# 4147  https://www.newsday.co.zw/2020/03/ed-orders-sc...  2020-03-24
# 4148  https://www.africanews.com/2020/03/27/coronavi...  2020-03-28
#
#                                      alternative_source
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4144                                                NaN
# 4145                                                NaN
# 4146                                                NaN
# 4147                                                NaN
# 4148  https://www.bbc.com/news/topics/crr7mlg0rpvt/z...
#
# [4149 rows x 17 columns]

# %%
ii=np.where(dat_4['country']=='Colombia')

# %%
dat_4['measure'][ii[0]]
# Out:
# 756                          State of emergency declared
# 757                  Introduction of quarantine policies
# 758    Additional health/documents requirements upon ...
# 759                                      Schools closure
# 760                                    Visa restrictions
# 761                  Introduction of quarantine policies
# 762    Additional health/documents requirements upon ...
# 763                          State of emergency declared
# 764                                       Border closure
# 765                                       Border closure
# 766                                     Partial lockdown
# 767                     International flights suspension
# 768                  Introduction of quarantine policies
# 769                              Limit public gatherings
# 770                                     Partial lockdown
# 771                         Domestic travel restrictions
# 772                                    Economic measures
# 773                                    Economic measures
# 774               Strengthening the public health system
# 775                                    Economic measures
# 776                                    Economic measures
# 777                                    Economic measures
# 778                                    Economic measures
# Name: measure, dtype: object

# %%
dat_5=pd.read_csv('global-school-closures-covid-19.csv')

# %%
dat_5.keys()
# Out:
# Index(['date', 'iso', 'country', 'scale', 'note'], dtype='object')

# %%
dat_5
# Out:
#             date  iso                                         country  \
# 0     2020-02-16  CHN                                           China
# 1     2020-02-16  CHN  China, Hong Kong Special Administrative Region
# 2     2020-02-16  CHN      China, Macao Special Administrative Region
# 3     2020-02-16  MNG                                        Mongolia
# 4     2020-02-17  CHN                                           China
# ...          ...  ...                                             ...
# 6407  2020-04-15  WSM                                           Samoa
# 6408  2020-04-15  YEM                                           Yemen
# 6409  2020-04-15  ZAF                                    South Africa
# 6410  2020-04-15  ZMB                                          Zambia
# 6411  2020-04-15  ZWE                                        Zimbabwe
#
#           scale                                               note
# 0     Localized                                                NaN
# 1     Localized                                                NaN
# 2     Localized                                                NaN
# 3      National  The government mandated school closures on 27 ...
# 4     Localized                                                NaN
# ...         ...                                                ...
# 6407   National                                                NaN
# 6408   National                                                NaN
# 6409   National                                                NaN
# 6410   National                                                NaN
# 6411   National                                                NaN
#
# [6412 rows x 5 columns]

# %%
c=np.where(dat_5['country']=='Colombia')

# %%
np.array(dat_5)[c[0],:]
# Out:
# array([['2020-03-16', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-17', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-18', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-19', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-20', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-21', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-22', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-23', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-24', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-25', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-26', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-27', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-28', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-29', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-30', 'COL', 'Colombia', 'National', nan],
#        ['2020-03-31', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-01', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-02', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-03', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-04', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-05', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-06', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-07', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-08', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-09', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-10', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-11', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-12', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-13', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-14', 'COL', 'Colombia', 'National', nan],
#        ['2020-04-15', 'COL', 'Colombia', 'National', nan]], dtype=object)

# %%
N=[]
B=set(dat_5['country'])
for i in B:
    m=np.where(dat_5['country']==i)
    N.append([len(m[0]),i])

# %%
N
# Out:
# [[23, 'New Zealand'],
#  [36, 'Romania'],
#  [35, 'Brazil'],
#  [31, 'Burkina Faso'],
#  [17, 'Central African republic'],
#  [34, 'Sri Lanka'],
#  [34, 'Denmark'],
#  [31, 'Namibia'],
#  [29, 'Finland'],
#  [31, 'Aruba'],
#  [27, 'Comoros'],
#  [27, 'Turks and Caicos Island'],
#  [35, 'Honduras'],
#  [31, 'Saint Vincent and the Grenadines'],
#  [16, 'Sierra Leone'],
#  [35, 'Norway'],
#  [50, 'Iran (Islamic Republic of)'],
#  [36, 'Spain'],
#  [31, 'Argentina'],
#  [29, 'Sweden'],
#  [17, 'Marshall Islands'],
#  [31, 'Myanmar'],
#  [33, 'Trinidad and Tobago'],
#  [20, 'Eritrea'],
#  [26, 'Madagascar'],
#  [60, 'Mongolia'],
#  [23, 'Cuba'],
#  [31, 'Mauritania'],
#  [48, 'Iraq'],
#  [24, 'Malawi'],
#  [35, 'Croatia'],
#  [24, 'Palau'],
#  [45, 'Georgia'],
#  [28, 'British Virgin Islands'],
#  [31, 'Monaco'],
#  [45, 'Armenia'],
#  [31, 'Austria'],
#  [44, 'Afghanistan'],
#  [31, 'Turkey'],
#  [33, 'Uruguay'],
#  [31, 'Bahamas'],
#  [29, 'Sint Marteen'],
#  [31, 'Uzbekistan'],
#  [31, 'Iceland'],
#  [48, 'Viet Nam'],
#  [31, 'Luxembourg'],
#  [34, 'Belgium'],
#  [27, 'Zambia'],
#  [44, 'France'],
#  [31, 'Morocco'],
#  [28, 'Eswatini'],
#  [39, 'Cambodia'],
#  [30, 'Bangladesh'],
#  [34, 'Latvia'],
#  [31, 'Bulgaria'],
#  [23, 'Cook Islands'],
#  [31, 'Faroe Islands'],
#  [31, 'Saint Lucia'],
#  [34, 'Cyprus'],
#  [31, 'Montserrat'],
#  [24, 'Dominica'],
#  [52, 'Italy'],
#  [17, 'Brunei Darussalam'],
#  [28, 'Greenland'],
#  [31, 'Kazakhstan'],
#  [36, 'Russian Federation'],
#  [27, 'Djibouti'],
#  [45, 'Republic of Korea'],
#  [35, 'Algeria'],
#  [24, 'Timor-Leste'],
#  [31, 'Chile'],
#  [31, 'Ethiopia'],
#  [34, 'Malta'],
#  [31, 'Serbia'],
#  [36, 'Paraguay'],
#  [24, 'Mexico'],
#  [38, 'Saudi Arabia'],
#  [24, 'Papua New Guinea'],
#  [29, 'Micronesia (Federated States of)'],
#  [35, 'Israel'],
#  [24, 'Belize'],
#  [23, 'Australia'],
#  [32, 'Oman'],
#  [52, 'San Marino'],
#  [31, 'Senegal'],
#  [29, 'Thailand'],
#  [39, 'United Arab Emirates'],
#  [34, 'Jamaica'],
#  [31, 'Estonia'],
#  [28, 'Lao PDR'],
#  [50, 'Bahrain'],
#  [46, 'Kuwait'],
#  [36, 'El Salvador'],
#  [31, 'Canada'],
#  [32, 'Jordan'],
#  [31, 'Netherlands'],
#  [42, 'Greece'],
#  [35, 'Switzerland'],
#  [48, 'United States of America'],
#  [36, 'Bosnia and Herzegovina'],
#  [37, 'Philippines'],
#  [31, 'Kyrgyzstan'],
#  [31, 'Surinam'],
#  [31, 'Kenya'],
#  [31, 'Liberia'],
#  [22, 'Guinea'],
#  [45, "Democratic People's Republic of Korea"],
#  [31, 'Poland'],
#  [31, 'Andorra'],
#  [45, 'Lebanon'],
#  [36, 'Hungary'],
#  [36, 'Republic of Moldova'],
#  [28, 'Lesotho'],
#  [44, 'Germany'],
#  [27, 'São Tomé and Príncipe'],
#  [28, 'Mauritius'],
#  [31, 'Sudan'],
#  [35, 'Ecuador'],
#  [30, "Cote d'Ivoire"],
#  [17, 'Benin'],
#  [24, 'Vanuatu'],
#  [28, 'United Republic of Tanzania'],
#  [49, 'Pakistan'],
#  [30, 'Guinea-Bissau'],
#  [31, 'Ghana'],
#  [31, 'Guatemala'],
#  [31, 'Lithuania'],
#  [27, 'Fiji'],
#  [36, 'North Macedonia'],
#  [41, 'Bhutan'],
#  [24, 'Gibraltar'],
#  [44, 'Azerbaijan'],
#  [48, 'United Kingdom of Great Britain and Northern Ireland'],
#  [31, 'Egypt'],
#  [28, 'Barbados'],
#  [31, 'Gabon'],
#  [3, 'Cabo Verde'],
#  [31, 'Colombia'],
#  [23, 'Zimbabwe'],
#  [31, 'Rwanda'],
#  [27, 'South Sudan'],
#  [60, 'China, Hong Kong Special Administrative Region'],
#  [29, 'South Africa'],
#  [60, 'China'],
#  [42, 'Portugal'],
#  [31, 'Syria Arab Republic'],
#  [31, 'Tunisia'],
#  [17, 'Kiribati'],
#  [27, 'Botswana'],
#  [35, 'Panama'],
#  [29, 'Malaysia'],
#  [29, 'Cameroon'],
#  [45, 'Japan'],
#  [28, 'Mali'],
#  [35, 'Bolivia (Plurinational State of)'],
#  [28, 'Dominican Republic'],
#  [20, 'Tonga'],
#  [30, 'Curaçao'],
#  [31, 'Equatorial Guinea'],
#  [27, 'Togo'],
#  [29, 'Somalia'],
#  [60, 'China, Macao Special Administrative Region'],
#  [23, 'Angola'],
#  [36, 'Albania'],
#  [33, 'Cayman Islands'],
#  [30, 'Costa Rica'],
#  [37, 'Slovakia'],
#  [27, 'Samoa'],
#  [24, 'Bermuda'],
#  [27, 'Chad'],
#  [24, 'Mozambique'],
#  [26, 'Niger'],
#  [31, 'Peru'],
#  [31, 'Grenada'],
#  [31, 'Guyana'],
#  [29, 'Nepal'],
#  [31, 'Venezuela'],
#  [31, 'Montenegro'],
#  [31, 'Liechtenstein'],
#  [31, 'Indonesia'],
#  [31, 'Slovenia'],
#  [32, 'Yemen'],
#  [31, 'Solomon Islands'],
#  [43, 'India'],
#  [28, 'Democratic Republic of the Congo'],
#  [35, 'Maldives'],
#  [34, 'Anguilla'],
#  [27, 'Uganda'],
#  [29, 'Gambia'],
#  [42, 'Palestine'],
#  [31, 'Seychelles'],
#  [36, 'Czechia'],
#  [41, 'Ukraine'],
#  [35, 'Ireland'],
#  [31, 'Libya'],
#  [21, 'Nigeria'],
#  [27, 'Haiti'],
#  [37, 'Qatar']]
